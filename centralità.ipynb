# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from networkx.algorithms import community

# %% [markdown]
# ### Lettura dataset e selezione dei soli giocatori in entrata (evitando così doppi trasferimenti e giocatori svincolati)

# %%
df = pd.read_csv('./dataset/dataset/transfers.csv')
dataset = df[df['dir'] == 'in']
dataset
# Out:
#       league  season window  team_id          team_name team_country dir  \
# 0        GB1    2009      s      985  Manchester United      England  in
# 1        GB1    2009      s      985  Manchester United      England  in
# 2        GB1    2009      s      985  Manchester United      England  in
# 3        GB1    2009      s      985  Manchester United      England  in
# 4        GB1    2009      s      985  Manchester United      England  in
# ...      ...     ...    ...      ...                ...          ...  ..
# 70000    NL1    2021      w      385    Fortuna Sittard  Netherlands  in
# 70001    NL1    2021      w      306      SC Heerenveen  Netherlands  in
# 70002    NL1    2021      w      306      SC Heerenveen  Netherlands  in
# 70003    NL1    2021      w      468   Sparta Rotterdam  Netherlands  in
# 70005    NL1    2021      w      499     Vitesse Arnhem  Netherlands  in
#
#        player_id        player_name  player_age  ... counter_team_id  \
# 0          33544   Antonio Valencia        23.0  ...            1071
# 1          62049         Mame Diouf        21.0  ...             687
# 2          43261    Gabriel Obertan        20.0  ...              40
# 3           1397       Michael Owen        29.0  ...             762
# 4          73538      Scott Moffatt        18.0  ...            5242
# ...          ...                ...         ...  ...             ...
# 70000     140032    Andreas Samaris        32.0  ...             515
# 70001     257808     Runar Espejord        25.0  ...            1293
# 70002     580142  Joaquín Fernández        22.0  ...           37535
# 70003     340353       Maduka Okoye        22.0  ...            1010
# 70005     187203    Eric Verstappen        27.0  ...             515
#
#             counter_team_name counter_team_country transfer_fee_amnt  \
# 0              Wigan Athletic              England        18800000.0
# 1                    Molde FK               Norway         4500000.0
# 2       FC Girondins Bordeaux               France         4000000.0
# 3            Newcastle United              England               0.0
# 4       Manchester United U18              England               NaN
# ...                       ...                  ...               ...
# 70000            Without Club         Without Club               NaN
# 70001               Tromsø IL               Norway               NaN
# 70002  Montevideo City Torque              Uruguay               NaN
# 70003              Watford FC              England               NaN
# 70005            Without Club         Without Club               NaN
#
#       market_val_amnt is_free  is_loan  is_loan_end  is_retired  transfer_id
# 0                 NaN   False    False        False       False       310832
# 1           1600000.0   False    False        False       False       319841
# 2            400000.0   False    False        False       False       315185
# 3                 NaN    True    False        False       False       306421
# 4                 NaN   False    False        False       False       339015
# ...               ...     ...      ...          ...         ...          ...
# 70000       1500000.0   False    False        False       False      3633188
# 70001        500000.0   False     True         True       False      3071862
# 70002        100000.0   False     True         True       False      3268245
# 70003       1000000.0   False     True        False       False      3619917
# 70005        125000.0   False    False        False       False      3611421
#
# [31934 rows x 23 columns]

# %%
print('colonna player_age Nan -> ' , dataset['player_age'].isna().sum())
print('colonna transfer_fee_amnt Nan -> ' , dataset['transfer_fee_amnt'].isna().sum())
print('colonna market_val_amnt Nan -> ' , dataset['market_val_amnt'].isna().sum())
print('colonna team_name Nan -> ' , dataset['team_name'].isna().sum())
print('colonna counter_team_name Nan -> ' , dataset['counter_team_name'].isna().sum())
retired_rows = dataset[(dataset['team_id'] == 'Retired') | (dataset['counter_team_id'] == 'Retired')]
print('colonne team_id o counter_team_id Retired -> ', retired_rows.shape[0])
print('Numero di campioni in cui la colonna is_loan_ended è True ->', (dataset['is_loan_end'] == True).sum())
# Out:
# colonna player_age Nan ->  6
# colonna transfer_fee_amnt Nan ->  18669
# colonna market_val_amnt Nan ->  7523
# colonna team_name Nan ->  0
# colonna counter_team_name Nan ->  0
# colonne team_id o counter_team_id Retired ->  2
# Numero di campioni in cui la colonna is_loan_ended è True -> 8719

# %% [markdown]
# ### Preprocessing:
# ##### - Rimuoviamo i 6 trasferimenti il cui player_age è Nan (per eventuali analisi future sull'età)
# ##### - Sostituiamo i Nan di transfer_fee_amnt con 0 (per eventuali analisi future sui valori di trasferimento)
# ##### - Sostituiamo i Nan di market_val_amnt con 0 (per eventuali analisi future sui valori di mercato)
# ##### - Seleziono solo i trasferimenti in cui la colonna 'counter_team_name' è diversa da 'Without Club' in quanto questa indica giocatori svincolati
# ##### - Seleziono solo i trasferimenti in cui la colonna 'team_name' è diversa da 'Without Club' in quanto questa indica l'ingaggio di giocatori svincolati
# #### - Rimuovo le righe in cui è presente in Counter_team_id e counter_team_name la parola Retired (ritirato)

# %%
# rimuovi i 6 player che non hanno età
dataset.dropna(subset=['player_age'], inplace=True)
# sostituisci i valori di trasferimento Nan con 0
dataset['transfer_fee_amnt'].fillna(0, inplace=True)
# sostituisci i valori di valore di mercato Nan con 0
dataset['market_val_amnt'].fillna(0, inplace=True)
# rimuovi i trasferimenti senza squadra di destinazione (ovvero svincoli)
dataset = dataset[dataset['counter_team_name'] != 'Without Club'] 
# rimuovi i trasferimenti senza squadra di provenienza (ovvero ingaggio di svincolati)
dataset = dataset[dataset['team_name'] != 'Without Club']
# Rimuovi le righe in cui 'team_id' o 'counter_team_id' sono uguali a 'Retired'
dataset = dataset[(dataset['team_id'] != 'Retired') & (dataset['counter_team_id'] != 'Retired')]
# Rimozione dei rientri dal prestito (is_loan_end = True)
dataset = dataset[dataset['is_loan_end'] == False]

# Conversione dei valori di 'team_id' e 'counter_team_id' in interi
dataset['team_id'] = dataset['team_id'].astype(int)
dataset['counter_team_id'] = dataset['counter_team_id'].astype(int)


print('Il dataset è composto da ', dataset.shape[0], ' trasferimenti')
# Out:
# Il dataset è composto da  22696  trasferimenti
# /var/folders/61/9rphml817c1d45n8g26p1ltm0000gn/T/ipykernel_5911/3190214965.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.dropna(subset=['player_age'], inplace=True)
# /var/folders/61/9rphml817c1d45n8g26p1ltm0000gn/T/ipykernel_5911/3190214965.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['transfer_fee_amnt'].fillna(0, inplace=True)
# /var/folders/61/9rphml817c1d45n8g26p1ltm0000gn/T/ipykernel_5911/3190214965.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['market_val_amnt'].fillna(0, inplace=True)

# %% [markdown]
# ### Inizio costruzione della rete
# #### Ogni team deve avere:
# ##### - un id
# ##### - un nome
# ##### - un paese e un codice lega (GB1 ad esempio)
# ### I team devono essere presi sia da team_name che da counter_team_name
# #### Ogni trasferimento deve avere:
# ##### - un id di trasferimento (?)
# ##### - un player id
# ##### - un player name
# ##### - l'età del player
# ##### - una season
# ##### - una finestra di mercato (invernale o estiva)
# ##### - un valore di trasferimento
# ##### - un bool che indica se è in prestito o a titolo definitivo
# ##### - il valore di mercato (?)

# %%
G = nx.MultiDiGraph()

for index, row in dataset.iterrows():
    player_name = row['player_name']
    
    # Utilizza l'ID della squadra come identificatore del nodo
    team1 = row['team_id']
    team2 = row['counter_team_id']
    
    if not G.has_node(team1):
        G.add_node(team1, label='team', name=row['team_name'], country=row['team_country'])
    if not G.has_node(team2):
        G.add_node(team2, label='team', name=row['counter_team_name'], country=row['counter_team_country'])
    
    transfer_attributes = {
        'transfer_id': row['transfer_id'],
        'player_id': row['player_id'],
        'player_name': row['player_name'],
        'player_age': row['player_age'],
        'season': row['season'],
        'window': row['window'],
        'transfer_fee_amnt': row['transfer_fee_amnt'],
        'is_loan': row['is_loan'],
        'market_val_amnt': row['market_val_amnt']
    }
    
    G.add_edge(team2, team1, label='transfer', **transfer_attributes) 

print('Numero di nodi:', G.number_of_nodes())
print('Numero di archi:', G.number_of_edges())
# Out:
# Numero di nodi: 2193
# Numero di archi: 22696

# %%
print('Nodi -> ', G.number_of_nodes())
print('Archi -> ', G.number_of_edges())
print('Density -> ', nx.density(G))
# Out:
# Nodi ->  2193
# Archi ->  22696
# Density ->  0.00472139288579122

# %% [markdown]
# Uno dei problemi che spesso si presenta in questa disciplina è l'esplosione delle reti, che sorge quando la rete cresce rapidamente in dimensioni e complessità a causa dell'aggiunta di nuovi nodi o archi.
# Questo fenomeno può influenzare notevolmente l'accuratezza e la significatività dei risultati ottenuti attraverso l'analisi delle reti.
# ### Seleziona solo i nodi che hanno almeno 10 archi in totale tra ingresso e uscita

# %%
# Calcola il grado dei nodi in ingresso e in uscita
in_degree = G.in_degree()
out_degree = G.out_degree()

# Crea un elenco dei nodi (team) che soddisfano il criterio di avere almeno un arco in ingresso e uno in uscita 
selected_teams = [node for node in G.nodes() if out_degree[node] > 0 and in_degree[node] > 0 ] 

print('Nodi selezionati -> ', len(selected_teams), ' nodi con almeno 10 operazioni di mercato')

# Crea un nuovo grafo (sottografo) basato sui nodi selezionati
net = G.subgraph(selected_teams)

net = net.copy()

# Identifica i nodi che soddisfano il criterio (transfer_fee_amnt uguale a 0 per tutti gli archi uscenti e entranti)
nodes_to_remove = []
for node in net.nodes():
    out_edges = net.out_edges(node, data=True)
    in_edges = net.in_edges(node, data=True)
        
    if all(attr['transfer_fee_amnt'] == 0 for _, _, attr in out_edges) and all(attr['transfer_fee_amnt'] == 0 for _, _, attr in in_edges):
        nodes_to_remove.append(node)

print('Nodi da rimuovere -> ', len(nodes_to_remove), ' nodi con tutte le operazioni di mercato a 0')

net.remove_nodes_from(nodes_to_remove)

print('Nodi -> ', net.number_of_nodes())
print('Archi -> ', net.number_of_edges())
print('Density -> ', nx.density(net))
# Out:
# Nodi selezionati ->  239  nodi con almeno 10 operazioni di mercato
# Nodi da rimuovere ->  3  nodi con tutte le operazioni di mercato a 0
# Nodi ->  236
# Archi ->  11648
# Density ->  0.21002524341868012

# %%
# Disegna il grafo
pos = nx.spring_layout(net)  # Posiziona i nodi in modo che siano ben distribuiti

# Disegna i nodi senza etichette
nx.draw(net, pos, with_labels=False, node_size=20, node_color='red')

# Disegna gli archi
nx.draw_networkx_edges(net, pos, width=0.02, edge_color='gray')

# Mostra il grafico
plt.axis('off')  # Nasconde gli assi
plt.show()

# %% [markdown]
# ## Misure: grado di centralità
# #### Misura il numero di connessioni in entrata e in uscita da un nodo all'interno della rete. I nodi con un grado di centralità più elevato sono considerati più importanti all'interno della rete poichè hanno più connessioni con altri nodi. Nel nostro caso può essere utilizzata per identificare quelli che sono i club più attivi e influenti nel calciomercato dal 2009 al 2021 così come quelli meno attivi. In particolare vengono identificati:
# #### - I nodi più importanti della rete -> maggior numero di connessioni con gli altri nodi. Indicano club più attivi e influenti.
# #### - I nodi di confine -> minor numero di connessioni. Indicano i club meno influenti nel calciomercato
# #### - Comunità -> la centralità di grado può essere utilizzata per identificare comunità di club. Le comunità sono gruppi di nodi altamente connessi tra loro e con meno connessioni ai nodi esterni al gruppo. Nel nostro caso può aiutare a identificare gruppi di club tra cui sono avvenuti molti trasferimenti nel periodo preso in esame.

# %%
# Cerca i club con il maggior numero di trasferimenti (senza utilizzare la rete)
'''
# Raggruppa i dati per squadra e conta i trasferimenti
team_transfers_count = dataset['team_name'].value_counts()

# Trova le prime 10 squadre con il maggior numero di trasferimenti
top_10_teams = team_transfers_count.head(10)

print("Le prime 10 squadre con il maggior numero di trasferimenti:")
print(top_10_teams)
'''

# Calcola il grado di centralità di tutti i nodi
degree_centrality = nx.degree_centrality(net)

club_presence_count = dict(net.degree())

# Ordina i nodi in base alla centralità di grado in ordine decrescente
sorted_nodes = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)

# Seleziona i primi 10 club più influenti / attivi
top_10_clubs = sorted_nodes[:10]

# Seleziona gli ultimi 10 club meno influenti / meno attivi
bottom_10_clubs = sorted_nodes[-10:]

# Stampa i risultati
print("I 10 club più influenti:")
for club, centrality in top_10_clubs:
    club_id = club
    club_name = G.nodes[club]['name']
    club_presence = club_presence_count[club_id]
    print("ID del club:", club_id, " - Nome del club: ", club_name, " - Centralità di grado: ", centrality, " - Presenze: ", club_presence)

print("\nI 10 club meno influenti:")
for club, centrality in bottom_10_clubs:
    club_id = club
    club_name = G.nodes[club]['name']
    club_presence = club_presence_count[club_id]
    print("ID del club:", club_id, " - Nome del club: ", club_name, " - Centralità di grado: ", centrality, " - Presenze: ", club_presence)
# Out:
# I 10 club più influenti:
# ID del club: 252  - Nome del club:  Genoa CFC  - Centralità di grado:  1.8553191489361702  - Presenze:  436
# ID del club: 46  - Nome del club:  FC Internazionale  - Centralità di grado:  1.4936170212765958  - Presenze:  351
# ID del club: 506  - Nome del club:  Juventus FC  - Centralità di grado:  1.4170212765957446  - Presenze:  333
# ID del club: 12  - Nome del club:  AS Roma  - Centralità di grado:  1.319148936170213  - Presenze:  310
# ID del club: 130  - Nome del club:  Parma Calcio 1913  - Centralità di grado:  1.319148936170213  - Presenze:  310
# ID del club: 5  - Nome del club:  AC Milan  - Centralità di grado:  1.2425531914893617  - Presenze:  292
# ID del club: 410  - Nome del club:  Udinese Calcio  - Centralità di grado:  1.2170212765957447  - Presenze:  286
# ID del club: 720  - Nome del club:  FC Porto  - Centralità di grado:  1.2127659574468086  - Presenze:  285
# ID del club: 294  - Nome del club:  SL Benfica  - Centralità di grado:  1.1787234042553192  - Presenze:  277
# ID del club: 1038  - Nome del club:  UC Sampdoria  - Centralità di grado:  1.1702127659574468  - Presenze:  275
#
# I 10 club meno influenti:
# ID del club: 4814  - Nome del club:  Naval 1º de Maio  - Centralità di grado:  0.0723404255319149  - Presenze:  17
# ID del club: 7971  - Nome del club:  Hércules CF  - Centralità di grado:  0.06808510638297872  - Presenze:  16
# ID del club: 35  - Nome del club:  FC St. Pauli  - Centralità di grado:  0.059574468085106386  - Presenze:  14
# ID del club: 648  - Nome del club:  CD Tenerife  - Centralità di grado:  0.055319148936170216  - Presenze:  13
# ID del club: 607  - Nome del club:  FBC Unione Venezia  - Centralità di grado:  0.05106382978723405  - Presenze:  12
# ID del club: 23  - Nome del club:  Eintracht Braunschweig  - Centralità di grado:  0.04680851063829787  - Presenze:  11
# ID del club: 1148  - Nome del club:  Brentford FC  - Centralità di grado:  0.04680851063829787  - Presenze:  11
# ID del club: 134  - Nome del club:  Xerez CD  - Centralità di grado:  0.0425531914893617  - Presenze:  10
# ID del club: 6912  - Nome del club:  FC Vizela  - Centralità di grado:  0.0425531914893617  - Presenze:  10
# ID del club: 3558  - Nome del club:  GFC Ajaccio  - Centralità di grado:  0.0425531914893617  - Presenze:  10

# %%
# Nodi più influenti e nodi meno influenti (di confine)

# Seleziona i nodi top 10 e bottom 10 insieme ai loro vicini
selected_nodes = [node for node, _ in top_10_clubs] + [node for node, _ in bottom_10_clubs]
subgraph = net.subgraph(selected_nodes)

# Estrai il sottografo completo che include tutti i nodi collegati ai nodi selezionati
full_subgraph = net.subgraph(list(subgraph.nodes) + [edge[1] for edge in net.edges(subgraph.nodes)])

# Crea una mappa di colori per i nodi
node_colors = []
node_sizes = []
for node in full_subgraph.nodes:
    if node in [club for club, _ in top_10_clubs]:
        node_colors.append('blue')  # Nodi top 10
        node_sizes.append(60)  # Dimensione più grande per i nodi blu
    elif node in [club for club, _ in bottom_10_clubs]:
        node_colors.append('green')  # Nodi bottom 10
        node_sizes.append(60)  # Dimensione più grande per i nodi verdi
    else:
        node_colors.append('red')  # Altri nodi
        node_sizes.append(20)  # Dimensione più piccola per i nodi rossi

# Disegna il grafo completo
pos = nx.kamada_kawai_layout(full_subgraph)
nx.draw(full_subgraph, pos, node_color=node_colors, with_labels=False, node_size=node_sizes, edge_color='gray', width=0.1)

# Visualizza il grafo
plt.show()

# %% [markdown]
# ## Team con più acquisti e cessioni

# %%
# Crea una lista di tuple (squadra, trasferimenti_in_uscita) per ogni squadra
outbound_transfers = {}

for team_node in net.nodes():
    team_name = net.nodes[team_node]['name']
    outbound_transfers[team_name] = 0

for team_node in net.nodes():
    out_edges = net.out_edges(team_node, data=True)
    for _, _, edge_attrs in out_edges:
        if edge_attrs['label'] == 'transfer':
            team_name = net.nodes[team_node]['name']
            outbound_transfers[team_name] += 1

# Ordina la lista in base al numero di trasferimenti in uscita in ordine decrescente
sorted_outbound_teams = sorted(outbound_transfers.items(), key=lambda x: x[1], reverse=True)

# Ottieni le prime 10 squadre con il maggior numero di trasferimenti in uscita
top_10_outbound_teams = sorted_outbound_teams[:10]

# Stampa le prime 10 squadre con il maggior numero di trasferimenti in uscita
for team_name, transfers in top_10_outbound_teams:
    print(f"Squadra: {team_name}")
    print(f"Trasferimenti in uscita: {transfers}")
    print()
# Out:
# Squadra: FC Internazionale
# Trasferimenti in uscita: 216
#
# Squadra: Chelsea FC
# Trasferimenti in uscita: 208
#
# Squadra: Genoa CFC
# Trasferimenti in uscita: 207
#
# Squadra: FC Porto
# Trasferimenti in uscita: 200
#
# Squadra: SL Benfica
# Trasferimenti in uscita: 193
#
# Squadra: Juventus FC
# Trasferimenti in uscita: 193
#
# Squadra: AS Roma
# Trasferimenti in uscita: 174
#
# Squadra: Udinese Calcio
# Trasferimenti in uscita: 167
#
# Squadra: Manchester City
# Trasferimenti in uscita: 157
#
# Squadra: Sporting CP
# Trasferimenti in uscita: 151

# %%
# Crea una lista di tuple (squadra, trasferimenti_in_entrata) per ogni squadra
inbound_transfers = {}

for team_node in net.nodes():
    team_name = net.nodes[team_node]['name']
    inbound_transfers[team_name] = 0

for team_node in net.nodes():
    in_edges = net.in_edges(team_node, data=True)
    for _, _, edge_attrs in in_edges:
        if edge_attrs['label'] == 'transfer':
            team_name = net.nodes[team_node]['name']
            inbound_transfers[team_name] += 1

# Ordina la lista in base al numero di trasferimenti in entrata in ordine decrescente
sorted_inbound_teams = sorted(inbound_transfers.items(), key=lambda x: x[1], reverse=True)

# Ottieni le prime 10 squadre con il maggior numero di trasferimenti in entrata
top_10_inbound_teams = sorted_inbound_teams[:10]

# Stampa le prime 10 squadre con il maggior numero di trasferimenti in entrata
for team_name, transfers in top_10_inbound_teams:
    print(f"Squadra: {team_name}")
    print(f"Trasferimenti in entrata: {transfers}")
    print()
# Out:
# Squadra: Genoa CFC
# Trasferimenti in entrata: 229
#
# Squadra: Parma Calcio 1913
# Trasferimenti in entrata: 203
#
# Squadra: UC Sampdoria
# Trasferimenti in entrata: 145
#
# Squadra: AC Milan
# Trasferimenti in entrata: 142
#
# Squadra: Juventus FC
# Trasferimenti in entrata: 140
#
# Squadra: AS Roma
# Trasferimenti in entrata: 136
#
# Squadra: FC Internazionale
# Trasferimenti in entrata: 135
#
# Squadra: ACF Fiorentina
# Trasferimenti in entrata: 131
#
# Squadra: Chievo Verona
# Trasferimenti in entrata: 125
#
# Squadra: Bologna FC 1909
# Trasferimenti in entrata: 123

# %%
# Crea un dizionario per tenere traccia del numero di trasferimenti per ogni calciatore
player_movement_count = {}

for (source, target, key) in net.edges(keys=True):
    player_name = net.edges[source, target, key]['player_name']
    
    # Se il calciatore non è presente nel dizionario, inizializza il conteggio a 1
    if player_name not in player_movement_count:
        player_movement_count[player_name] = 1
    else:
        # Altrimenti, incrementa il conteggio di 1
        player_movement_count[player_name] += 1

# Ordina i calciatori in base al numero di trasferimenti in ordine decrescente
sorted_players = sorted(player_movement_count.items(), key=lambda x: x[1], reverse=True)

# Ottieni i primi 5 calciatori più mobili
top_5_mobile_players = sorted_players[:5]

# Stampa i nomi dei calciatori e il numero di trasferimenti per i primi 5 calciatori più mobili
for player_name, movement_count in top_5_mobile_players:
    print(f"Calciatore: {player_name}, Numero di Trasferimenti: {movement_count}")
# Out:
# Calciatore: Mattia Destro, Numero di Trasferimenti: 10
# Calciatore: Emiliano Viviano, Numero di Trasferimenti: 10
# Calciatore: Kevin-Prince Boateng, Numero di Trasferimenti: 10
# Calciatore: Valerio Verre, Numero di Trasferimenti: 10
# Calciatore: Roberto, Numero di Trasferimenti: 10

# %% [markdown]
# ## Community
# ##### Le "community" (o comunità) in un grafo rappresentano gruppi di nodi all'interno del grafo che sono più fortemente connessi tra loro rispetto ai nodi al di fuori del gruppo. L'obiettivo dell'analisi delle comunità è identificare tali gruppi o cluster di nodi all'interno del grafo, in modo da poter studiare le relazioni e i pattern tra i membri delle comunità. Le community possono rivelare strutture e modelli significativi all'interno del grafo.
#
# ##### Ecco alcune informazioni sulle community:
#
# ##### Definizione delle community: Non esiste una definizione universale delle community in un grafo. La definizione può variare a seconda dell'applicazione e degli obiettivi dell'analisi. Tuttavia, in generale, una community è spesso definita come un insieme di nodi altamente connessi, dove la connettività tra i membri della comunità è più forte rispetto alla connettività con i nodi al di fuori della comunità.
# ##### Rilevamento delle community: L'analisi delle community comporta il rilevamento di queste strutture all'interno del grafo. Esistono vari algoritmi di rilevamento delle community, come il "greedy modularity-based algorithm", il "Louvain algorithm," e altri. Questi algoritmi cercano di massimizzare la modularità del grafo, che misura quanto le comunità siano ben definite all'interno del grafo.
# ##### Interpretazione delle community: Una volta identificate le community, è importante interpretare cosa rappresentano. Ad esempio, in un grafo delle interazioni sociali, le community potrebbero rappresentare gruppi di amici o interessi comuni. In un grafo delle reti informatiche, le community potrebbero rappresentare sottoreti di dispositivi connessi tra loro.
# ##### Utilità delle community: Le community possono essere utili per vari scopi, tra cui la segmentazione del pubblico, l'individuazione di gruppi di utenti con interessi simili, l'analisi delle reti sociali, la rilevazione di gruppi di nodi fortemente connessi in una rete complessa, e molto altro.
# ##### Visualizzazione delle community: È comune rappresentare le community utilizzando colori diversi per i nodi all'interno di ciascuna community. Questo rende più facile identificare e visualizzare le strutture delle community all'interno del grafo.
# ##### Le community sono uno strumento importante nell'analisi delle reti complesse e possono rivelare informazioni significative sulle relazioni all'interno del grafo. La comprensione delle community può aiutare a svelare modelli, strutture e comportamenti all'interno di una rete.

# %%
# Converti il grafo in un grafo non direzionato
undirected_net = net.to_undirected()

# Esegui l'algoritmo di rilevamento delle comunità sul grafo non direzionato
communities = list(nx.algorithms.community.greedy_modularity_communities(undirected_net))


# Stampa le comunità identificate con i nomi dei team
for i, community in enumerate(communities):
    team_names = [undirected_net.nodes[node]['name'] for node in community]
    print(f"Community {i + 1}: {team_names}")


# Crea un dizionario che associa i nodi alle comunità
node_to_community = {}
for i, community in enumerate(communities):
    for node in community:
        node_to_community[node] = i

# Crea una lista di colori per le comunità
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

# Estrai i colori dei nodi in base alle comunità
node_colors = [colors[node_to_community[node] % len(colors)] for node in undirected_net.nodes()]


pos = nx.kamada_kawai_layout(undirected_net)
nx.draw(undirected_net, pos, node_color=node_colors, with_labels=False, node_size=20, edge_color='gray', width=0.1)

# Visualizza il grafo
plt.show()
# Out:
# Community 1: ['Stoke City', 'Reading FC', 'Arsenal FC', 'Queens Park Rangers', 'Manchester City', 'Valencia CF', 'Villarreal CF', 'Everton FC', 'Liverpool FC', 'Sunderland AFC', 'Girona FC', 'Hércules CF', 'Levante UD', 'Wigan Athletic', 'Málaga CF', 'CA Osasuna', 'Birmingham City', 'Deportivo Alavés', 'Cardiff City', 'Sheffield United', 'Norwich City', 'Bolton Wanderers', 'Crystal Palace', 'Burnley FC', 'Athletic Bilbao', 'Real Valladolid CF', 'Rayo Vallecano', 'Sevilla FC', 'Racing Santander', 'West Ham United', 'Brentford FC', 'Getafe CF', 'Cádiz CF', 'Middlesbrough FC', 'FC Barcelona', 'Xerez CD', 'CD Tenerife', 'Real Zaragoza', 'Leeds United', 'Sporting Gijón', 'Tottenham Hotspur', 'Aston Villa', 'Real Betis Balompié', 'Granada CF', 'Blackpool FC', 'Real Madrid', 'Fulham FC', 'Blackburn Rovers', 'Real Sociedad', 'Celta de Vigo', 'Southampton FC', 'Hull City', 'RCD Espanyol Barcelona', 'West Bromwich Albion', 'Manchester United', 'UD Las Palmas', 'CD Leganés', 'AFC Bournemouth', 'Córdoba CF', 'UD Almería', 'Leicester City', 'RCD Mallorca', 'SD Huesca', 'Swansea City', 'Watford FC', 'Elche CF', 'Portsmouth FC', 'SD Eibar']
# Community 2: ['US Boulogne', 'FC Lorient', 'AS Nancy-Lorraine', 'Amiens SC', 'Nîmes Olympique', 'Grenoble Foot 38', 'SM Caen', 'Le Mans FC', 'SCO Angers', 'Stade Reims', 'Valenciennes FC', 'Stade Rennais FC', 'Olympique Lyon', 'Dijon FCO', 'RC Strasbourg Alsace', 'FC Toulouse', 'OGC Nice', 'AJ Auxerre', 'AS Monaco', 'FC Girondins Bordeaux', 'LOSC Lille', 'RC Lens', 'Clermont Foot Auvergne 63', 'ESTAC Troyes', 'Paris Saint-Germain', 'Montpellier HSC', 'Stade Brestois 29', 'SC Bastia', 'EA Guingamp', 'FC Metz', 'FC Évian Thonon Gaillard', 'FC Nantes', 'GFC Ajaccio', 'AS Saint-Étienne', 'FC Sochaux-Montbéliard', 'Olympique Marseille', 'Newcastle United', 'AC Ajaccio']
# Community 3: ['Bologna FC 1909', 'Parma Calcio 1913', 'AC Milan', 'Carpi FC 1909', 'Frosinone Calcio', 'AS Roma', 'SS Lazio', 'UC Sampdoria', 'Brescia Calcio', 'Hellas Verona', 'AC Cesena', 'Udinese Calcio', 'Atalanta BC', 'Torino FC', 'SPAL 1907', 'Novara Calcio 1908', 'ACF Fiorentina', 'FC Internazionale', 'US Sassuolo', 'SSC Napoli', 'AS Livorno', 'Spezia Calcio', 'US Palermo', 'Benevento Calcio', 'AS Bari', 'Calcio Catania', 'Chievo Verona', 'FBC Unione Venezia', 'Delfino Pescara 1936', 'Robur Siena', 'US Lecce', 'Empoli FC', 'Cagliari Calcio', 'FC Crotone', 'Salernitana Calcio 1919', 'Juventus FC', 'Genoa CFC']
# Community 4: ['FC Vizela', 'Deportivo de La Coruña', 'FC Famalicão', 'Desportivo Aves', 'CD Tondela', 'Atlético de Madrid', 'SC Olhanense', 'Leixões SC', 'CD Feirense', 'CS Marítimo', 'Belenenses SAD', 'SC Beira-Mar', 'Wolverhampton Wanderers', 'SL Benfica', 'Académica Coimbra', 'SC Braga', 'FC Paços de Ferreira', 'GD Estoril Praia', 'Vitória Setúbal FC', 'Boavista FC', 'Naval 1º de Maio', 'União de Leiria', 'Sporting CP', 'FC Porto', 'Portimonense SC', 'Moreirense FC', 'CD Nacional', 'FC Arouca', 'Vitória Guimarães SC', 'CD Santa Clara', 'Gil Vicente FC', 'Rio Ave FC', 'GD Chaves', 'FC Penafiel']
# Community 5: ['SpVgg Greuther Fürth', '1.FC Kaiserslautern', '1. FC Köln', '1.FC Nuremberg', 'Arminia Bielefeld', 'Bayer 04 Leverkusen', 'VfL Bochum', 'VfB Stuttgart', 'Borussia Dortmund', 'Borussia Mönchengladbach', 'VfL Wolfsburg', 'TSG 1899 Hoffenheim', 'Huddersfield Town', 'SV Werder Bremen', 'Eintracht Braunschweig', 'RB Leipzig', 'Eintracht Frankfurt', '1.FC Union Berlin', 'Bayern Munich', 'FC Schalke 04', 'FC St. Pauli', 'Fortuna Düsseldorf', '1.FSV Mainz 05', 'FC Augsburg', 'SV Darmstadt 98', 'Hamburger SV', 'Hannover 96', 'Hertha BSC', 'FC Ingolstadt 04', 'SC Freiburg', 'SC Paderborn 07']
# Community 6: ['Roda JC Kerkrade', 'Fortuna Sittard', 'De Graafschap Doetinchem', 'FC Emmen', 'AZ Alkmaar', 'NAC Breda', 'SC Cambuur-Leeuwarden', 'FC Utrecht', 'FC Groningen', 'VVV-Venlo', 'NEC Nijmegen', 'Willem II Tilburg', 'Brighton & Hove Albion', 'Sparta Rotterdam', 'Heracles Almelo', 'Go Ahead Eagles', 'Excelsior Rotterdam', 'Ajax Amsterdam', 'Feyenoord Rotterdam', 'RKC Waalwijk', 'FC Dordrecht', 'SC Heerenveen', 'Vitesse Arnhem', 'ADO Den Haag', 'PEC Zwolle', 'Chelsea FC', 'Twente Enschede FC', 'PSV Eindhoven']

# %% [markdown]
# ## Centralità Betweenness
# ##### Se i nodi nella tua rete rappresentano i club e gli archi rappresentano i trasferimenti tra club, allora la centralità di intermediarietà applicata ai club avrà un significato diverso rispetto a quanto precedentemente discusso per i calciatori. In questo caso, la centralità di intermediarietà misurerà l'importanza dei club nella facilitazione dei trasferimenti tra altri club. Ecco come puoi interpretare la centralità di intermediarietà in questo contesto:
#
# ##### 1 - Club intermediari: I club con una centralità di intermediarietà elevata saranno quelli che sono spesso coinvolti come intermediari nei trasferimenti tra altri club. Potrebbero essere squadre che fungono da ponti tra diverse squadre e partecipano attivamente a numerosi trasferimenti.
# ##### 2 - Influenza nei trasferimenti: I club con alta centralità di intermediarietà possono esercitare un'influenza significativa nel mercato dei trasferimenti. Possono essere considerati squadre chiave nel facilitare le operazioni di mercato tra altri club.
# ##### 3 -Gestione del mercato: Questi club potrebbero avere una posizione strategica nel mercato dei trasferimenti e potrebbero essere coinvolti in una serie di negoziazioni. La loro importanza potrebbe derivare dalla loro capacità di accogliere o cedere giocatori ad altri club.
# ##### 4 -Collegamento tra club: La centralità di intermediarietà riflette il ruolo di questi club come collegamenti tra altre squadre, contribuendo a connettere i trasferimenti tra le squadre coinvolte.

# %%
# Calcola la centralità di intermediarietà
betweenness_centrality = nx.betweenness_centrality(net)

# Ordina i nodi in base alla centralità di intermediarietà in ordine decrescente
sorted_nodes = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)

# Seleziona i primi 10 nodi con la centralità più alta
top_10_nodes = sorted_nodes[:10]

# Crea un nuovo sottografo contenente solo i primi 10 nodi
top_10_subgraph = net.subgraph([node for node, _ in top_10_nodes])

# Stampa le informazioni dei primi 10 nodi
print("Top 10 nodi con alta centralità di intermediarietà:")
for node, centrality in top_10_nodes:
    club_name = top_10_subgraph.nodes[node].get("name", "Nome sconosciuto")
    print(f"Nodo {node} (Club: {club_name}): Centralità di Intermediarietà = {centrality}")

# Disegna e mostra il sottografo dei top 10 nodi
plt.figure(figsize=(6, 6))  # Dimensioni del grafico
pos = nx.spring_layout(top_10_subgraph, seed=42)  # Layout per la disposizione dei nodi
nx.draw(top_10_subgraph, pos, with_labels=True, node_size=800, node_color="lightblue", font_size=10, font_color="black", font_weight="bold")
plt.title("Top 10 Nodi con Alta Centralità di Intermediarietà")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/manuelplacella/Desktop/SNA_Project/centralità.ipynb Cella 23 line 2
#       <a href='vscode-notebook-cell:/Users/manuelplacella/Desktop/SNA_Project/centralit%C3%A0.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> # Calcola la centralità di intermediarietà
# ----> <a href='vscode-notebook-cell:/Users/manuelplacella/Desktop/SNA_Project/centralit%C3%A0.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> betweenness_centrality = nx.betweenness_centrality(net)
#       <a href='vscode-notebook-cell:/Users/manuelplacella/Desktop/SNA_Project/centralit%C3%A0.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a> # Ordina i nodi in base alla centralità di intermediarietà in ordine decrescente
#       <a href='vscode-notebook-cell:/Users/manuelplacella/Desktop/SNA_Project/centralit%C3%A0.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a> sorted_nodes = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)
#
# NameError: name 'net' is not defined

# %% [markdown]
# ## Grado medio ponderato
# ##### Il grado medio ponderato indica l'importanza media dei team in base al valore finanziario dei trasferimenti di giocatori associati a ciascun team. In altre parole, rappresenta l'importanza media di una squadra nel mercato dei trasferimenti dei giocatori. Quando calcoli il grado medio ponderato, stai considerando il valore totale dei trasferimenti in entrata e in uscita per ciascun team e lo dividi per il numero di tali trasferimenti. Questo valore rappresenta una stima dell'importanza finanziaria media di ciascun team nella rete di trasferimenti dei giocatori. Un grado medio ponderato più alto indica che un team è coinvolto in trasferimenti di giocatori di valore superiore, mentre un grado medio ponderato più basso indica trasferimenti di valore inferiore.
# #### Si può usare questa metrica per identificare le squadre che sono economicamente più influenti nella rete dei trasferimenti dei giocatori. Le squadre con un grado medio ponderato più alto sono quelle che sono coinvolte in trasferimenti di giocatori con un valore finanziario complessivamente più alto rispetto alle altre squadre.

# %%
# Inizializza un dizionario per memorizzare il grado medio ponderato di ciascun nodo
weighted_degrees = {}

# Calcola il grado medio ponderato per ciascun nodo
for node in net.nodes():
    if net.nodes[node]['label'] == 'team':
        total_in_weight_sum = 0
        total_out_weight_sum = 0
        in_node_count = 0
        out_node_count = 0
        
        for _, _, data in net.in_edges(node, data=True):
            total_in_weight_sum += data['transfer_fee_amnt']
            in_node_count += 1
        
        for _, _, data in net.out_edges(node, data=True):
            total_out_weight_sum += data['transfer_fee_amnt']
            out_node_count += 1

        if in_node_count > 0 and out_node_count > 0:
            average_weighted_degree = (total_in_weight_sum + total_out_weight_sum) / (in_node_count + out_node_count)
            weighted_degrees[node] = average_weighted_degree

# Ordina i nodi in base al grado medio ponderato in ordine decrescente
sorted_weighted_degrees = sorted(weighted_degrees.items(), key=lambda x: x[1], reverse=True)

# Stampa i primi 10 nodi con il grado medio ponderato più alto, includendo il nome del team
for i, (node, weighted_degree) in enumerate(sorted_weighted_degrees[:10]):
    team_name = net.nodes[node]['name']
    print(f"Nodo: {node}, Nome Team: {team_name}, Grado Medio Ponderato: {weighted_degree}")
# Out:
# Nodo: 985, Nome Team: Manchester United, Grado Medio Ponderato: 14410634.328358209
# Nodo: 6692, Nome Team: Novara Calcio 1908, Grado Medio Ponderato: 14029729.72972973
# Nodo: 131, Nome Team: FC Barcelona, Grado Medio Ponderato: 14005147.928994082
# Nodo: 418, Nome Team: Real Madrid, Grado Medio Ponderato: 12934269.662921349
# Nodo: 1148, Nome Team: Brentford FC, Grado Medio Ponderato: 11072272.727272727
# Nodo: 31, Nome Team: Liverpool FC, Grado Medio Ponderato: 10939880.952380951
# Nodo: 281, Nome Team: Manchester City, Grado Medio Ponderato: 10681606.33484163
# Nodo: 1003, Nome Team: Leicester City, Grado Medio Ponderato: 10662500.0
# Nodo: 16, Nome Team: Borussia Dortmund, Grado Medio Ponderato: 10608458.64661654
# Nodo: 583, Nome Team: Paris Saint-Germain, Grado Medio Ponderato: 10442559.523809524

# %% [markdown]
# ## Centralità di vicinanza
# ##### Nel contesto della tua rete in cui i nodi rappresentano i club e gli archi rappresentano i trasferimenti dei giocatori, la centralità di vicinanza di un nodo indicherebbe quanto quel club è "vicino" agli altri club in termini di trasferimenti dei giocatori. Un club con una alta centralità di vicinanza avrebbe molte connessioni di trasferimento con altri club nella rete, il che potrebbe suggerire una maggiore interazione o flusso di giocatori tra quel club e gli altri club.
# ##### Ad esempio, se un club A ha una alta centralità di vicinanza nella tua rete, ciò potrebbe significare che il club A ha effettuato numerosi trasferimenti di giocatori con molti altri club nella rete. Questo può indicare che il club A è fortemente coinvolto nel mercato dei trasferimenti dei giocatori e ha relazioni strette con altri club.
# ##### Puoi utilizzare la centralità di vicinanza per identificare i club che sono centrali nella tua rete di trasferimenti dei giocatori e che giocano un ruolo significativo nella dinamica dei trasferimenti tra i club. I club con una alta centralità di vicinanza potrebbero essere considerati importanti attori nella tua rete di trasferimenti.

# %%
# Calcola la centralità di vicinanza
closeness_centrality = nx.closeness_centrality(net)

# Ordina i nodi in base alla centralità di vicinanza in ordine decrescente
sorted_nodes = sorted(closeness_centrality.items(), key=lambda x: x[1], reverse=True)

# Seleziona i primi 10 nodi con la centralità più alta
top_10_nodes = sorted_nodes[:10]

# Crea un nuovo sottografo contenente solo i primi 10 nodi
top_10_subgraph = net.subgraph([node for node, _ in top_10_nodes])

# Stampa le informazioni dei primi 10 nodi
print("Top 10 nodi con alta centralità di vicinanza:")
for node, centrality in top_10_nodes:
    club_name = top_10_subgraph.nodes[node].get("name", "Nome sconosciuto")
    print(f"Nodo {node} (Club: {club_name}): Centralità di Vicinanza = {centrality}")

# Disegna e mostra il sottografo dei top 10 nodi
plt.figure(figsize=(6, 6))  # Dimensioni del grafico
pos = nx.spring_layout(top_10_subgraph, seed=42)  # Layout per la disposizione dei nodi
nx.draw(top_10_subgraph, pos, with_labels=True, node_size=800, node_color="lightblue", font_size=10, font_color="black", font_weight="bold")
plt.title("Top 10 Nodi con Alta Centralità di Vicinanza")
plt.axis("off")
plt.show()
# Out:
# Top 10 nodi con alta centralità di vicinanza:
# Nodo 252 (Club: Genoa CFC): Centralità di Vicinanza = 0.5759803921568627
# Nodo 368 (Club: Sevilla FC): Centralità di Vicinanza = 0.573170731707317
# Nodo 1084 (Club: Málaga CF): Centralità di Vicinanza = 0.556872037914692
# Nodo 162 (Club: AS Monaco): Centralità di Vicinanza = 0.556872037914692
# Nodo 336 (Club: Sporting CP): Centralità di Vicinanza = 0.556872037914692
# Nodo 430 (Club: ACF Fiorentina): Centralità di Vicinanza = 0.550351288056206
# Nodo 618 (Club: AS Saint-Étienne): Centralità di Vicinanza = 0.5452436194895591
# Nodo 294 (Club: SL Benfica): Centralità di Vicinanza = 0.5452436194895591
# Nodo 1038 (Club: UC Sampdoria): Centralità di Vicinanza = 0.5439814814814815
# Nodo 398 (Club: SS Lazio): Centralità di Vicinanza = 0.5427251732101617

# %% [markdown]
# ## Centralità di autovettori
# ##### Nel contesto della tua rete in cui i nodi rappresentano i club e gli archi rappresentano i trasferimenti dei giocatori, la centralità di autovettori indica l'importanza relativa dei club all'interno della rete dei trasferimenti dei giocatori. Questa metrica tiene conto del fatto che i club connessi ad altri club importanti avranno una centralità di autovettori più elevata.
# ##### Un club con una alta centralità di autovettori sarà un club che è connesso a club importanti attraverso trasferimenti di giocatori. In altre parole, è probabile che sia coinvolto in trasferimenti con club di alto profilo o club che sono centrali nella rete.
# ##### La centralità di autovettori può aiutarti a identificare i club che giocano un ruolo significativo nella dinamica dei trasferimenti dei giocatori e che sono connessi ad altri club importanti nella rete. Questa metrica può essere utile per individuare i club chiave o influenti nella tua rete di trasferimenti dei giocatori.
#
# ### La centralità di autovettori è disponibile solo per i grafi standard (non direzionati e non multigrafi) in NetworkX. Per questo la rete viene trasformata in un grafo semplice

# %%
# Converti il multigrafo in un grafo standard
net_standard = nx.Graph(net)

# Calcola la centralità di autovettori sul grafo standard
eigenvector_centrality = nx.eigenvector_centrality(net_standard)

# Ordina i nodi in base alla centralità di autovettori in ordine decrescente
sorted_nodes = sorted(eigenvector_centrality.items(), key=lambda x: x[1], reverse=True)

# Seleziona i primi 10 nodi con la centralità più alta
top_10_nodes = sorted_nodes[:10]

# Crea un nuovo sottografo contenente solo i primi 10 nodi
top_10_subgraph = net.subgraph([node for node, _ in top_10_nodes])

# Stampa le informazioni dei primi 10 nodi
print("Top 10 nodi con alta centralità di autovettori:")
for node, centrality in top_10_nodes:
    club_name = top_10_subgraph.nodes[node].get("name", "Nome sconosciuto")
    print(f"Nodo {node} (Club: {club_name}): Centralità di Autovettori = {centrality}")

# Disegna e mostra il sottografo dei top 10 nodi
plt.figure(figsize=(6, 6))  # Dimensioni del grafico
pos = nx.spring_layout(top_10_subgraph, seed=42)  # Layout per la disposizione dei nodi
nx.draw(top_10_subgraph, pos, with_labels=True, node_size=800, node_color="lightblue", font_size=10, font_color="black", font_weight="bold")
plt.title("Top 10 Nodi con Alta Centralità di Autovettori")
plt.axis("off")
plt.show()
# Out:
# Top 10 nodi con alta centralità di autovettori:
# Nodo 368 (Club: Sevilla FC): Centralità di Autovettori = 0.1460219022497747
# Nodo 631 (Club: Chelsea FC): Centralità di Autovettori = 0.14295279352939125
# Nodo 336 (Club: Sporting CP): Centralità di Autovettori = 0.13396631823004765
# Nodo 162 (Club: AS Monaco): Centralità di Autovettori = 0.13105115944192303
# Nodo 281 (Club: Manchester City): Centralità di Autovettori = 0.1287129354035188
# Nodo 294 (Club: SL Benfica): Centralità di Autovettori = 0.12707979817012355
# Nodo 720 (Club: FC Porto): Centralità di Autovettori = 0.12451939754702036
# Nodo 12 (Club: AS Roma): Centralità di Autovettori = 0.1242949258682128
# Nodo 11 (Club: Arsenal FC): Centralità di Autovettori = 0.12396495921462022
# Nodo 5 (Club: AC Milan): Centralità di Autovettori = 0.1231044927072739

# %% [markdown]
# ##### La scelta tra la centralità di autovettori e la centralità di Katz dipende dall'obiettivo specifico della tua analisi e dalla natura della tua rete dei trasferimenti dei giocatori tra club di calcio. Entrambe le metriche sono utili, ma hanno alcune differenze chiave:
#
# ##### Centralità di Autovettori:
# ##### Misura l'importanza di un nodo in base alle connessioni con altri nodi importanti nella rete.
# ##### Il calcolo si basa sul concetto di autovettori della matrice di adiacenza.
# ##### Adatta quando vuoi identificare nodi connessi ad altri nodi importanti nella rete.
# ##### Può essere influenzata da nodi con una sola connessione a un nodo molto importante.
# ##### Centralità di Katz:
# ##### Misura l'importanza di un nodo in base alle connessioni dirette e indirette con altri nodi, pesando le catene di connessioni.
# ##### Il calcolo si basa su una combinazione lineare delle centralità dei vicini.
# ##### Adatta quando vuoi identificare nodi connessi a catene di nodi importanti nella rete.
# ##### Meno sensibile alle connessioni dirette con un solo nodo molto importante.
# ##### La scelta tra le due metriche dipende dalla struttura della tua rete e dai tuoi obiettivi analitici. Puoi considerare di utilizzare entrambe le metriche e confrontarle per ottenere una visione più completa dell'importanza dei club di calcio nella rete dei trasferimenti dei giocatori.

# %%
# Converti il multigrafo in un grafo standard
net_standard = nx.Graph(net)

# Definisci il parametro di attenuazione alpha (deve essere inferiore all'inverso del massimo autovalore della matrice di adiacenza)
alpha = 0.01  # Puoi regolare questo valore in base alle tue esigenze.

# Calcola la centralità di Katz
katz_centrality = nx.katz_centrality(net_standard, alpha=alpha)

# Ordina i nodi in base alla centralità di Katz in ordine decrescente
sorted_nodes = sorted(katz_centrality.items(), key=lambda x: x[1], reverse=True)

# Seleziona i primi 10 nodi con la centralità più alta
top_10_nodes = sorted_nodes[:10]

# Crea un nuovo sottografo contenente solo i primi 10 nodi
top_10_subgraph = net.subgraph([node for node, _ in top_10_nodes])

# Stampa le informazioni dei primi 10 nodi
print("Top 10 nodi con alta centralità di Katz:")
for node, centrality in top_10_nodes:
    club_name = top_10_subgraph.nodes[node].get("name", "Nome sconosciuto")
    print(f"Nodo {node} (Club: {club_name}): Centralità di Katz = {centrality}")

# Disegna e mostra il sottografo dei top 10 nodi
plt.figure(figsize=(6, 6))  # Dimensioni del grafico
pos = nx.spring_layout(top_10_subgraph, seed=42)  # Layout per la disposizione dei nodi
nx.draw(top_10_subgraph, pos, with_labels=True, node_size=800, node_color="lightblue", font_size=10, font_color="black", font_weight="bold")
plt.title("Top 10 Nodi con Alta Centralità di Katz")
plt.axis("off")
plt.show()
# Out:
# Top 10 nodi con alta centralità di Katz:
# Nodo 368 (Club: Sevilla FC): Centralità di Katz = 0.10791031056980402
# Nodo 631 (Club: Chelsea FC): Centralità di Katz = 0.10714161470594029
# Nodo 336 (Club: Sporting CP): Centralità di Katz = 0.1062591922259398
# Nodo 162 (Club: AS Monaco): Centralità di Katz = 0.10257295424592182
# Nodo 294 (Club: SL Benfica): Centralità di Katz = 0.10089155347865199
# Nodo 720 (Club: FC Porto): Centralità di Katz = 0.10028351091920111
# Nodo 281 (Club: Manchester City): Centralità di Katz = 0.09986075077245195
# Nodo 12 (Club: AS Roma): Centralità di Katz = 0.09640167628419402
# Nodo 46 (Club: FC Internazionale): Centralità di Katz = 0.09560387419772876
# Nodo 11 (Club: Arsenal FC): Centralità di Katz = 0.09515917696981947
